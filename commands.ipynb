# %%
from zaber_cli import ZaberCLI
zaber = ZaberCLI()
zaber.connect("COM4")
axis = zaber.axis

axis.home()
# Out:
# Device fully connected
# ---------------------------------------------------------------------------
# MovementFailedException                   Traceback (most recent call last)
# Cell In[2], line 6
#       3 zaber.connect("COM4")
#       4 axis = zaber.axis
# ----> 6 axis.home()
#
# File c:\Users\donna\AppData\Local\Programs\Python\Python311\Lib\site-packages\zaber_motion\ascii\axis.py:146, in Axis.home(self, wait_until_idle)
#     134 """
#     135 Homes axis. Axis returns to its homing position.
#     136
#     137 Args:
#     138     wait_until_idle: Determines whether function should return after the movement is finished or just started.
#     139 """
#     140 request = dto.DeviceHomeRequest(
#     141     interface_id=self.device.connection.interface_id,
#     142     device=self.device.device_address,
#     143     axis=self.axis_number,
#     144     wait_until_idle=wait_until_idle,
#     145 )
# --> 146 call("device/home", request)
#
# File c:\Users\donna\AppData\Local\Programs\Python\Python311\Lib\site-packages\zaber_motion\call.py:69, in call(request, data, make_response)
#      65     raise RuntimeError(f"Invalid result code: {result}")
#      67 response_buffers = promise.get()
# ---> 69 return process_response(response_buffers, make_response)
#
# File c:\Users\donna\AppData\Local\Programs\Python\Python311\Lib\site-packages\zaber_motion\call.py:188, in process_response(response_buffers, make_response)
#     186 if response_dto.response != dto.ResponseType.OK:
#     187     if len(response_buffers) > 1:
# --> 188         raise convert_exception(response_dto.error_type, response_dto.error_message, response_buffers[1])
#     189     raise convert_exception(response_dto.error_type, response_dto.error_message)
#     191 if len(response_buffers) > 1:
#
# MovementFailedException: MovementFailedException: Movement may have failed because fault was observed: Stalled and Stopped (FS).

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# Load the data
path = Path("data") / "Run.xlsx"
df = pd.read_excel(path, index_col=0)

# Inspect column names and first few rows
print("Columns:", list(df.columns))
print(df.head())

# Assume columns 2-4 are load cells and column 5 is time.
# Adjust if the file has different column names/order.
load_cells = df.iloc[:, 0:3]
time = df.iloc[:, 3]

# Convert time to elapsed time (assuming it's in seconds)
elapsed = time - time.iloc[0]

# Plot all three load cells on one chart
plt.figure(figsize=(10, 6))
for col in load_cells.columns:
    plt.plot(elapsed, load_cells[col], label=col)

plt.xlabel("Elapsed time")
plt.ylabel("Pressure (N)")
plt.title("Loadcell Pressures vs Elapsed Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
